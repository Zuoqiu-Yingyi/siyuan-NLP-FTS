# %%
import json

import pkg.env as env

from pkg.api import API
from pkg.notebook import Notebook, Notebooks
from pkg.client import Client
from pkg.tree import Tree

# %%
client = Client(
    token=env.token,
    host=env.host,
    port=env.port,
    ssl=env.ssl,
    proxies=env.proxies,
)

# %%
notebooks = client.getNotebooks()

# %%
tree = Tree(
    client=client,
    notebooks=notebooks,
)

# %%
tree.buildTree(
    # '20210808180117-czj9bvb',  # notebook 用户指南
    # '20221223102407-2a0djn8',  # doc 课程论文
    '20221125094240-jdfn6ce',  # doc 网络空间安全领域智能化
)
tree
# Out:
# {'alias': '', 'box': '20210918102434-mtrd8yr', 'content': '网络空间安全领域智能化', 'hpath': '/人工智能与机器学习/网络空间安全领域智能化', 'id': '20221125094240-jdfn6ce', 'memo': '', 'name': '', 'path': '/20220909082530-85ixym4/20221125094240-jdfn6ce.sy'} []
# - root
# | - 课程
# | | - 人工智能与机器学习
# | | | - 网络空间安全领域智能化
# | | | | - 网络空间安全领域的智能化
# | | | | | - 形式化验证与推理
# | | | | | | - 协议安全性验证
# | | | | | | | - 协议安全性验证
# | | | | | | | - 推理
# | | | | | | | | - 基于回答集逻辑编程 (ASP) 的网络协议安全性验证
# | | | | | | | | - 基于ASP的中间人攻击检测模型
# | | | | | | | | - 推理
# | | | | | - ​image :二于RHEEHP RHETIN机器学习在网络空间安全中的典型应用应用软件安全社会网络安全问题抽象社交网络异常帐号检测垃圾邮件检测⋅⋅基于URL 的恶意网页识别他网二扰洛近测恶意PDF 从测RE 数据采集| 数据预处理及网络基础设施安全网络安全检测安全特征提取僵尸网络检测BGP 异常检测网络入侵检测技术[| |亚意域名检测恶意加密流量识别模型构建— J芯片安全系统硬件及物理环境安全系统软件安全模型验证⋅⋅⋅ moo-ism劣质芯片检测设备身份认证硬件木马检测密码设备边信道攻击pala 一一一一PUF 攻击伪基站检测和效果评估一HEIDE | SMUGRS assets/image-20221223094706-nm9ch2o.png ​
# | | | | | - 联动、协作与合作
# | | | | | | - 攻击和防御
# | | | | | | | - 多Agent技术
# | | | | | | | | - 基于粒子群算法的虚拟社区发现模型
# | | | | | | | | - 基于多Agent技术的网络安全态势感知
# | | | | | | | | - 基于多Agent技术的多策略分布式智能协同防火墙
# | | | | | | | | - 多Agent技术
# | | | | | | | - 群体智能
# | | | | | | | - 攻击和防御
# | | | | | - 必要性
# | | | | | | - 孤立的网络防护设备，缺乏联动能力
# | | | | | | - 发现未知威胁的困难性
# | | | | | | - 缺乏自学习、自提升的能力
# | | | | | - 博弈
# | | | | | | - 网络对抗与合作博弈
# | | | | | | | - 博弈论
# | | | | | | | | - 基于生成对抗网络的网络对抗策略生成
# | | | | | | | | - 博弈论
# | | | | | | | - 网络对抗与合作博弈
# | | | | | | | - 强化学习
# | | | | | | | | - 基于强化学习的网络对抗策略生成
# | | | | | | | | - 强化学习
# | | | | | | | - 深度学习
# | | | | | | | | - 基于机器学习的信任评估
# | | | | | | | | - 深度学习
# | | | | | - 自适应与预测
# | | | | | | - 未知威胁发现与应对
# | | | | | | | - 序列预测
# | | | | | | | | - 基于循环神经网络的网络安全态势预测
# | | | | | | | | - 序列预测
# | | | | | | | - 自适应学习
# | | | | | | | - 未知威胁发现与应对
# | | | | | | | - 仿生智能
# | | | | | | | | - 基于免疫原理的入侵检测
# | | | | | | | | - 仿生智能
# | | | | | | | | - 基于人工蜂群算法的双门限认知无线电网络的攻击检测算法
# | | | | | | | | - 基于群体多样性免疫技术的容侵容错软件多变体构造技术
# | | | | | | | - 强化学习
# | | | | | | | | - 引入强化学习机制的网络动态路由规划模型
# | | | | | | | | - 强化学习
# | | | | | - 模式识别
# | | | | | | - 内容识别和包特征识别
# | | | | | | | - 内容识别和包特征识别
# | | | | | | | - 归纳学习与深度学习
# | | | | | | | | - 基于决策树学习的入侵检测
# | | | | | | | | - 基于机器学习的高级持续威胁 (APT) 检测
# | | | | | | | | - 基于深度学习的入侵检测
# | | | | | | | | - 联合使用 CNN 和 LSTM 的恶意流量检测
# | | | | | | | | - 基于贝叶斯方法的垃圾邮件检测专家系统
# | | | | | | | | - 归纳学习与深度学习
# | | | | | | | - 模式聚类与模式分类
# | | | | | - 大数据分析
# | | | | | | - 数据隐私、网络测量与内容情感分析
# | | | | | | | - 深度学习
# | | | | | | | - 数据挖掘与知识发现
# | | | | | | | | - 基于数据挖掘技术的社交网络舆情分析
# | | | | | | | | - 基于大数据智能分析技术的隐私挖掘
# | | | | | | | | - 数据挖掘与知识发现
# | | | | | | | | - 基于深度学习的网络测量数据异常挖掘
# | | | | | | | - 类别不平衡的机器学习
# | | | | | | | | - 类别不平衡的机器学习
# | | | | | | | | - 基于机器学习的情感分析模型
# | | | | | | | - 数据隐私、网络测量与内容情感分析
# | | | | - 人工智能安全
# | | | | | - 学习模型安全
# | | | | | | - 学习模型安全
# | | | | | | - 模型防御
# | | | | | | - 模型参数提取攻击
# | | | | | | - 模型对抗
# | | | | | | | - 影子模型
# | | | | | | | - 模型对抗
# | | | | | | | - 模型反演攻击
# | | | | | - 知识库安全
# | | | | | | - 知识库攻击
# | | | | | | | - 矛盾知识注入使推理失效
# | | | | | | | - 知识库攻击
# | | | | | | - 知识库安全
# | | | | | - 数据挖掘安全
# | | | | | | - 数据挖掘安全
# | | | | | | - 虚假数据注入，误导挖掘结果
# | | | | | - 学习模型的健壮性分析
# | | | | | - 学习模型训练数据安全
# | | | | | | - 对抗样本生成
# | | | | | | | - 加噪声
# | | | | | | | - 对抗样本生成
# | | | | | | | - 误导分类
# | | | | | | - 学习模型训练数据安全
# | | | | | | - 训练数据隐私保护
# | | | | | | | - 训练数据隐私保护
# | | | | | | | - 分布式联合训练
# | | | | - 网络空间安全及主要研究内容
# | | | | | - 系统安全
# | | | | | | - 虚拟化及安全
# | | | | | | - 公共系统安全—公共云安全
# | | | | | | - 跨系统的访问控制与授权管理
# | | | | | | - 系统访问安全
# | | | | | | - 系统恢复
# | | | | | | - 可信计算
# | | | | | | - 系统攻击
# | | | | | | - 大型应用系统安全
# | | | | | | | - 电子商务系统安全
# | | | | | | | - 智慧城市安全
# | | | | | | | - 大型应用系统安全
# | | | | | | | - 物联网系统安全（无人智能系统安全）
# | | | | | | - 系统入侵检测
# | | | | | - 组织安全
# | | | | | | - 风险评估方法与模型
# | | | | | | - 安全治理 (Security Governance)
# | | | | | | - 网络空间安全规划 (Cybersecurity Planning)
# | | | | | | - 灾难恢复与应急响应
# | | | | | - 社会安全
# | | | | | | - 网络空间犯罪 (Cyber-Crime )
# | | | | | | - 网络空间道德 (Cyber-Ethics)
# | | | | | | - 网络空间法律 (Cyber-Law)
# | | | | | | - 舆情监测
# | | | | | | - 网络空间政策 (Cyber-Policy)
# | | | | | | - 社交网络与社团挖掘
# | | | | | - 数据安全与内容安全
# | | | | | | - 数字水印与信息隐藏
# | | | | | | - 数字取证 (Digital Forensics)
# | | | | | | - 数据完整性和真实性 (Data Integrity and Authentication)
# | | | | | | - 数据挖掘与隐私保护 (Data Mining & Privacy Protect)
# | | | | | | - 信息存储安全 (Information Storage Security)
# | | | | | | - 密码学 (Cryptography) 与数字签名
# | | | | | | - 图像、声音、文本内容情感分析
# | | | | | | - 数据访问控制 (Data Access Control)
# | | | | | | - 安全通信协议 (Secure Communication Protocol)
# | | | | | | | - 多方计算与零知识证明协议
# | | | | | | | - 安全通信协议 (Secure Communication Protocol)
# | | | | | - 连接安全
# | | | | | | - 物联网络连接安全
# | | | | | | - 匿名通信
# | | | | | | - 电力网络连接安全
# | | | | | | - 复杂网络安全理论与技术
# | | | | | | | - 流行性传播模型与抗毁性模型
# | | | | | | | - 复杂网络安全理论与技术
# | | | | | | - 通信网络连接安全
# | | | | | | | - 通信网络连接安全
# | | | | | | | - 无线、卫星、移动、广播、电视通信网络连接安全
# | | | | | | - 互联网络连接安全
# | | | | | | | - 互联网络连接安全
# | | | | | | | - 网络防御 (Network Defense)
# | | | | | | | - Web安全
# | | | | | | | - 网络攻击 (Network Attack) 与网络对抗
# | | | | | | | - 网络安全监测与防护
# | | | | | | | | - 网络入侵检测
# | | | | | | | | - 网络安全监测与防护
# | | | | | | | | - 防火墙
# | | | | | | | | - 蜜罐技术
# | | | | | | | - 网络安全协议设计与分析
# | | | | | - 软件安全
# | | | | | | - 恶意移动应用检测与防御
# | | | | | | - 可信与安全软件设计方法学
# | | | | | | - 操作系统安全
# | | | | | | - 容侵容错的软件多变体构造技术
# | | | | | | - 二进制代码分析与逆向工程
# | | | | | | - 软件可靠性与健壮性分析
# | | | | | | - 软件代码随机化技术
# | | | | | | - 软件漏洞分析与挖掘
# | | | | | | | - 内存泄漏
# | | | | | | | - 病毒
# | | | | | | | - 代码注入
# | | | | | | | - 软件漏洞分析与挖掘
# | | | | | - 组件安全
# | | | | | | - 组件供应链管理 (Supply Chain Management) 风险与安全分析及组件可信度分析方法
# | | | | | | - 组件设计中的安全分析
# | | | | | | - 组件测试安全机制
# | | | | | | - 安全组件设计方法学
# | | | | | - 人员安全
# | | | | | | - 社会工程攻击检测与防御
# | | | | | | - 身份识别安全
# | | | | | | - 社会与行为隐私保护
# | | | | | | - 个人数据隐私保护与安全
# | | | | - 什么是网络空间安全
# | | | | | - 安全 (Security/Safety)
# | | | | | | - 没有收到威胁、危险、危害、损失
# | | | | | | - Safety
# | | | | | | | - 是指被保护起来的状态和感觉，偏向情感
# | | | | | | | - Safety
# | | | | | | - Security
# | | | | | | | - Security
# | | | | | | | - 聚焦于有意施加伤害的行为，侧重保护的行动
# | | | | | | - 通过持续的危险识别和风险管理过程，将伤害或损失的风险降低并保持在可接受的水平或其以下
# | | | | | - 网络空间 (Cyber-Space)
# | | | | | | - 连接各种信息技术网络构成的多维空间
# | | | | | | | - 互联网
# | | | | | | | - 工业控制网
# | | | | | | | - 电力网
# | | | | | | | - 物联网
# | | | | | | | - 移动网
# | | | | | | | - 通信网
# | | | | | | | - 连接各种信息技术网络构成的多维空间
# | | | | | | - 网络空间的特征
# | | | | | | | - 网络空间的特征
# | | | | | | | - 具有空间客观存在性、全球性、管理的非中心化特征
# | | | | | - 网络空间安全 (Cyber-Security)
# | | | | | | - 核心是信息安全与网络安全
# | | | | | | - 涉及技术、人、信息和过程
# | | | | | | - 以计算技术为基础
# | | | | | | - 可测、可信、可控
# | | | | | | - 面向网络空间，在存在对手的情况下，使操作有保障

# %%
# tree._map

# %%
# print(json.dumps(tree.__dict__(), indent=2, ensure_ascii=False))
